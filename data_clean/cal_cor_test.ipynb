# %%
import pandas as pd

# %%
import lib.corcoordinate_caculate as cc

# %%
main_data = pd.read_csv('../data/內政部實價登錄_data/台北市_10101_11303_房價data.csv')
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243176 entries, 0 to 243175
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     243176 non-null  int64
#  1   usage_category                 242958 non-null  object
#  2   address                        243176 non-null  object
#  3   property_type                  243174 non-null  object
#  4   community_name                 136206 non-null  object
#  5   main_building_ratio            227424 non-null  float64
#  6   city                           243176 non-null  object
#  7   parking_space_price            38223 non-null   float64
#  8   transaction_date               243176 non-null  object
#  9   elevator_available             83323 non-null   float64
#  10  building_age                   196408 non-null  float64
#  11  number_of_land                 243176 non-null  int64
# ...

# %%
main_data['longitude']
# Out:
# 0         121.562364
# 1         121.521735
# 2         121.529696
# 3         121.534162
# 4         121.506940
#              ...
# 243171    121.586622
# 243172    121.586622
# 243173    121.586622
# 243174    121.614110
# 243175    121.589574
# Name: longitude, Length: 243176, dtype: float64

# %%
test_data = main_data[['latitude','longitude']].head(100)

# %%
test_data.head()
# Out:
#     latitude   longitude
# 0  25.109841  121.562364
# 1  25.083014  121.521735
# 2  25.096835  121.529696
# 3  25.125402  121.534162
# 4  25.084347  121.506940

# %%
high_speed = pd.read_excel('../data/迎避設施 集中營/高速公路出入口.xlsx')

# %%
high_speed.head()
# Out:
#          分類     設施名稱 里程K+000       位置座標X      位置座標Y
# 0  國道1號(平面)      基隆端       0  121.735785  25.122895
# 1  國道1號(平面)    基隆交流道       1  121.729195  25.116244
# 2  國道1號(平面)    八堵交流道       2  121.720896  25.103529
# 3  國道1號(平面)  大華系統交流道       5  121.699802  25.097373
# 4  國道1號(平面)    五堵交流道       6  121.689182  25.087178

# %%
cc.convert_lat_lon_to_tuple(high_speed, '位置座標Y', '位置座標X')

# %%
high_speed
# Out:
#           分類     設施名稱 里程K+000       位置座標X      位置座標Y  \
# 0   國道1號(平面)      基隆端       0  121.735785  25.122895
# 1   國道1號(平面)    基隆交流道       1  121.729195  25.116244
# 2   國道1號(平面)    八堵交流道       2  121.720896  25.103529
# 3   國道1號(平面)  大華系統交流道       5  121.699802  25.097373
# 4   國道1號(平面)    五堵交流道       6  121.689182  25.087178
# 5   國道1號(平面)    汐止交流道      10  121.659572  25.076205
# 6   國道1號(平面)  汐止系統交流道      11  121.650189  25.073493
# 7   國道1號(平面)  高架道路汐止端      13  121.631931  25.067370
# 8   國道1號(平面)    東湖交流道      15  121.612227  25.065466
# 9   國道1號(平面)    內湖交流道      17  121.592575  25.064261
# 10  國道1號(平面)    圓山交流道      23  121.534794  25.072724
# 11  國道1號(平面)    台北交流道      25  121.515936  25.077702
# 12  國道1號(平面)    三重交流道      27  121.496356  25.076243
# 13  國道1號(平面)    五股轉接道      32  121.448203  25.071558
# 14  國道1號(平面)    五股交流道      33  121.438723  25.068942
# 15  國道1號(平面)    泰山轉接道      35  121.420051  25.064329
# 16  國道1號(平面)    林口交流道      41  121.367971  25.065149
# ...

# %%
cc.convert_lat_lon_to_tuple(test_data, 'latitude', 'longitude')

# %%
test_data
# Out:
#      latitude   longitude                                       cor
# 0   25.109841  121.562364   (25.109841388999303, 121.5623636414188)
# 1   25.083014  121.521735    (25.08301416710221, 121.5217354205053)
# 2   25.096835  121.529696  (25.096834957429344, 121.52969579806587)
# 3   25.125402  121.534162  (25.125401572552573, 121.53416242019422)
# 4   25.084347  121.506940    (25.0843474191753, 121.50694037083063)
# ..        ...         ...                                       ...
# 95  25.145982  121.552293    (25.14598203785791, 121.5522934210285)
# 96  25.108477  121.530946   (25.10847660792752, 121.53094570109276)
# 97  25.119258  121.525409   (25.11925771327323, 121.52540945664502)
# 98  25.088221  121.506718  (25.088221217528435, 121.50671839944884)
# 99  25.090693  121.517862   (25.09069253315644, 121.51786189785864)
#
# [100 rows x 3 columns]

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitude   100 non-null    float64
#  1   longitude  100 non-null    float64
#  2   cor        100 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB

# %%
cc.distance_caculate_and_cat_counts(test_data, high_speed, 'hs', [1000,3000,5000])

# %%
test_data
# Out:
#      latitude   longitude                                       cor  \
# 0   25.109841  121.562364   (25.109841388999303, 121.5623636414188)
# 1   25.083014  121.521735    (25.08301416710221, 121.5217354205053)
# 2   25.096835  121.529696  (25.096834957429344, 121.52969579806587)
# 3   25.125402  121.534162  (25.125401572552573, 121.53416242019422)
# 4   25.084347  121.506940    (25.0843474191753, 121.50694037083063)
# ..        ...         ...                                       ...
# 95  25.145982  121.552293    (25.14598203785791, 121.5522934210285)
# 96  25.108477  121.530946   (25.10847660792752, 121.53094570109276)
# 97  25.119258  121.525409   (25.11925771327323, 121.52540945664502)
# 98  25.088221  121.506718  (25.088221217528435, 121.50671839944884)
# 99  25.090693  121.517862   (25.09069253315644, 121.51786189785864)
#
#     hs_under_1000_m  hs_under_3000_m  hs_under_5000_m
# 0               0.0              0.0              2.0
# ...
