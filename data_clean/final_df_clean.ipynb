# %%
import pandas as pd

# %%
df = pd.read_csv("./taipei_main_data_house.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243176 entries, 0 to 243175
# Columns: 109 entries, Unnamed: 0.2 to 醫療設施_under_750_m
# dtypes: float64(89), int64(8), object(12)
# memory usage: 204.1+ MB

# %%
# 台北新北要先分開做，不然會有重複的問題(因為原本是獨立的表格會有相同的index)
df = df.sort_values('Unnamed: 0.1')

# %%
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 usage_category  \
# 0             0             0           0              住
# 1             1             1           1              住
# 2             2             2           2              住
# 3             3             3           3              住
# 4             4             4           4              住
#
#                                        address  property_type community_name  \
# 0         士林區中社路一段０１１巷００７２號四樓#士林區中社路一段１１巷７２號四樓   公寓(5樓含以下無電梯)            NaN
# 1             士林區後港街０２０巷００１８號四樓#士林區後港街２０巷１８號四樓   公寓(5樓含以下無電梯)            NaN
# 2       士林區中正路１０４巷００１弄０００２號四樓#士林區中正路１０４巷１弄２號四樓  華廈(10層含以下有電梯)            NaN
# 3  士林區中山北路七段１９０巷００１６之３號７樓#士林區中山北路七段１９０巷１６之３號７樓  華廈(10層含以下有電梯)           海山華廈
# 4      士林區延平北路五段２８５巷００８９號四樓#士林區延平北路五段２８５巷８９號四樓   套房(1房(1廳)1衛)             硯藏
#
#    main_building_ratio city  parking_space_price  ... 療養院_under_750_m  \
# 0               100.00    A                  NaN  ...             0.0
# ...

# %%
new_df = pd.read_csv("./new_taipei_main_data_house.csv")

# %%
new_df = new_df.sort_values('Unnamed: 0.1')

# %%
final_df = pd.concat([df, new_df], axis=0, ignore_index=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806578 entries, 0 to 806577
# Columns: 109 entries, Unnamed: 0.2 to 醫療設施_under_750_m
# dtypes: float64(89), int64(8), object(12)
# memory usage: 670.8+ MB

# %%
final_df[243170:243180]
# Out:
#         Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 usage_category  \
# 243170            70        243170      243170              住
# 243171            71        243171      243171              住
# 243172            72        243172      243172              住
# 243173            73        243173      243173              住
# 243174            74        243174      243174              工
# 243175            75        243175      243175              工
# 243176             0             0           0              住
# 243177             1             1           1            NaN
# 243178             2             2           2              住
# 243179             3             3           3              住
#
#                                           address    property_type  \
# 243170  南港區東新街１８０巷００１１號地下一層之９#南港區東新街１８０巷１１號地下一層之９  住宅大樓(11層含以上有電梯)
# 243171               南港區忠孝東路六段０１８６號#南港區忠孝東路六段１８６號     公寓(5樓含以下無電梯)
# 243172           南港區忠孝東路六段０１８６號三樓#南港區忠孝東路六段１８６號三樓     公寓(5樓含以下無電梯)
# ...

# %%
final_df.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'usage_category',
#        'address', 'property_type', 'community_name', 'main_building_ratio',
#        'city', 'parking_space_price',
#        ...
#        '療養院_under_750_m', '診所_under_250_m', '診所_under_500_m', '診所_under_750_m',
#        '藥局_under_250_m', '藥局_under_500_m', '藥局_under_750_m',
#        '醫療設施_under_250_m', '醫療設施_under_500_m', '醫療設施_under_750_m'],
#       dtype='object', length=109)

# %%
final_df.head(1)
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 usage_category  \
# 0             0             0           0              住
#
#                                 address property_type community_name  \
# 0  士林區中社路一段０１１巷００７２號四樓#士林區中社路一段１１巷７２號四樓  公寓(5樓含以下無電梯)            NaN
#
#    main_building_ratio city  parking_space_price  ... 療養院_under_750_m  \
# 0                100.0    A                  NaN  ...             0.0
#
#    診所_under_250_m  診所_under_500_m  診所_under_750_m  藥局_under_250_m  \
# 0             0.0             0.0             0.0             0.0
#
#    藥局_under_500_m  藥局_under_750_m  醫療設施_under_250_m  醫療設施_under_500_m  \
# 0             0.0             0.0               0.0               0.0
#
#   醫療設施_under_750_m
# 0              0.0
#
# [1 rows x 109 columns]

# %%
final_df = final_df.drop(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0'],axis=1)

# %%
final_df.columns
# Out:
# Index(['usage_category', 'address', 'property_type', 'community_name',
#        'main_building_ratio', 'city', 'parking_space_price',
#        'transaction_date', 'elevator_available', 'building_age',
#        ...
#        '療養院_under_750_m', '診所_under_250_m', '診所_under_500_m', '診所_under_750_m',
#        '藥局_under_250_m', '藥局_under_500_m', '藥局_under_750_m',
#        '醫療設施_under_250_m', '醫療設施_under_500_m', '醫療設施_under_750_m'],
#       dtype='object', length=106)

# %%
final_df.head(1)
# Out:
#   usage_category                               address property_type  \
# 0              住  士林區中社路一段０１１巷００７２號四樓#士林區中社路一段１１巷７２號四樓  公寓(5樓含以下無電梯)
#
#   community_name  main_building_ratio city  parking_space_price  \
# 0            NaN                100.0    A                  NaN
#
#   transaction_date  elevator_available  building_age  ...  療養院_under_750_m  \
# 0       2016-12-08                 NaN          41.0  ...              0.0
#
#    診所_under_250_m  診所_under_500_m  診所_under_750_m  藥局_under_250_m  \
# 0             0.0             0.0             0.0             0.0
#
#    藥局_under_500_m 藥局_under_750_m 醫療設施_under_250_m  醫療設施_under_500_m  \
# 0             0.0            0.0              0.0               0.0
#
#   醫療設施_under_750_m
# 0              0.0
#
# [1 rows x 106 columns]

# %%
final_df.to_csv('./final_main_data_and_near_facility.csv', encoding="utf-8", index=False)

# %%
import lib.df_combine_and_re_duplicated as dcr

# %%
dcr.combine_file_under_dir('./ok_near_facility_新北_check/', './new_taipei.csv')

# %%
fff = pd.read_csv('./new_taipei.csv')

# %%
fff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Columns: 109 entries, Unnamed: 0.2 to 醫療設施_under_750_m
# dtypes: float64(89), int64(8), object(12)
# memory usage: 83.2+ MB
